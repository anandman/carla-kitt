# %%
import traffic_light_detector
# Out:
# /Users/macbook/miniconda2/envs/carla-kitt-env/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/macbook/miniconda2/envs/carla-kitt-env/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Train the model using the test.record dataset with labels
import importlib
importlib.reload(traffic_light_detector)

tl = traffic_light_detector.TLDetector('faster_rcnn_inception_v2_coco_2018_01_28', 'mscoco_label_map')

# %%
tl.get_truncated_model_for_training()
# Out:
# add/y
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/TensorArrayStack_4/range/delta
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/TensorArrayStack_4/range/start
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/TensorArrayStack_2/range/delta
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/TensorArrayStack_2/range/start
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/TensorArrayStack_1/range/delta
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/TensorArrayStack_1/range/start
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/TensorArrayStack/range/delta
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/TensorArrayStack/range/start
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/Const
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/Enter
# SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/Merge
# ...

# %%
# Import image data files
import glob

image_fnames = glob.glob("../../../data/udacity/*")
print(image_fnames)
# Out:
# ['../../../data/udacity/left0000.jpg', '../../../data/udacity/left0183.jpg', '../../../data/udacity/left0140.jpg']

# %%
# Import labels (TODO)

# %%
# Train model

# %%
# Save model
